-- %%
synset_words = torch.load('synset.t7','ascii')

-- %%
print(synset_words)
-- Out:
-- {
--   1 : tench, Tinca tinca
--   2 : goldfish, Carassius auratus
--   3 : great white shark, white shark, man-eater, man-eating shark, Carcharodon carcharias
--   4 : tiger shark, Galeocerdo cuvieri
--   5 : hammerhead, hammerhead shark
--   6 : electric ray, crampfish, numbfish, torpedo
--   7 : stingray
--   8 : cock
--   9 : hen
--   10 : ostrich, Struthio camelus
--   11 : brambling, Fringilla montifringilla
--   12 : goldfinch, Carduelis carduelis
--   13 : house finch, linnet, Carpodacus mexicanus
--   14 : junco, snowbird
--   15 : indigo bunting, indigo finch, indigo bird, Passerina cyanea
--   16 : robin, American robin, Turdus migratorius
--   17 : bulbul
--   18 : jay
--   19 : magpie
--   20 : chickadee
--   21 : water ouzel, dipper
--   22 : kite
--   23 : bald eagle, American eagle, Haliaeetus leucocephalus
--   24 : vulture
--   25 : great grey owl, great gray owl, Strix nebulosa
--   26 : European fire salamander, Salamandra salamandra
-- ...

-- %%
print(torch.load('synset.t7'))
-- Out:
-- /Users/amdegroot/torch/install/share/lua/5.1/torch/File.lua:375: unknown object
-- stack traceback:
-- 	[C]: in function 'error'
-- 	/Users/amdegroot/torch/install/share/lua/5.1/torch/File.lua:375: in function 'readObject'
-- 	/Users/amdegroot/torch/install/share/lua/5.1/torch/File.lua:409: in function 'load'
-- 	[string "print(torch.load('synset.t7'))..."]:1: in main chunk
-- 	[C]: in function 'xpcall'
-- 	...rs/amdegroot/torch/install/share/lua/5.1/itorch/main.lua:209: in function <...rs/amdegroot/torch/install/share/lua/5.1/itorch/main.lua:173>
-- 	...rs/amdegroot/torch/install/share/lua/5.1/lzmq/poller.lua:75: in function 'poll'
-- 	...amdegroot/torch/install/share/lua/5.1/lzmq/impl/loop.lua:307: in function 'poll'
-- 	...amdegroot/torch/install/share/lua/5.1/lzmq/impl/loop.lua:325: in function 'sleep_ex'
-- 	...amdegroot/torch/install/share/lua/5.1/lzmq/impl/loop.lua:370: in function 'start'
-- 	...rs/amdegroot/torch/install/share/lua/5.1/itorch/main.lua:381: in main chunk
-- ...

-- %%
classes = torch.load('synset.t7')
-- Out:
-- /Users/amdegroot/torch/install/share/lua/5.1/torch/File.lua:375: unknown object
-- stack traceback:
-- 	[C]: in function 'error'
-- 	/Users/amdegroot/torch/install/share/lua/5.1/torch/File.lua:375: in function 'readObject'
-- 	/Users/amdegroot/torch/install/share/lua/5.1/torch/File.lua:409: in function 'load'
-- 	[string "classes = torch.load('synset.t7')..."]:1: in main chunk
-- 	[C]: in function 'xpcall'
-- 	...rs/amdegroot/torch/install/share/lua/5.1/itorch/main.lua:209: in function <...rs/amdegroot/torch/install/share/lua/5.1/itorch/main.lua:173>
-- 	...rs/amdegroot/torch/install/share/lua/5.1/lzmq/poller.lua:75: in function 'poll'
-- 	...amdegroot/torch/install/share/lua/5.1/lzmq/impl/loop.lua:307: in function 'poll'
-- 	...amdegroot/torch/install/share/lua/5.1/lzmq/impl/loop.lua:325: in function 'sleep_ex'
-- 	...amdegroot/torch/install/share/lua/5.1/lzmq/impl/loop.lua:370: in function 'start'
-- 	...rs/amdegroot/torch/install/share/lua/5.1/itorch/main.lua:381: in main chunk
-- ...

-- %%
synset.t7
-- Out:
-- [string "local f = function() return synset.t7 end; lo..."]:1: attempt to index global 'synset' (a nil value)
-- stack traceback:
-- 	[string "local f = function() return synset.t7 end; lo..."]:1: in function 'f'
-- 	[string "local f = function() return synset.t7 end; lo..."]:1: in main chunk
-- 	[C]: in function 'xpcall'
-- 	...rs/amdegroot/torch/install/share/lua/5.1/itorch/main.lua:209: in function <...rs/amdegroot/torch/install/share/lua/5.1/itorch/main.lua:173>
-- 	...rs/amdegroot/torch/install/share/lua/5.1/lzmq/poller.lua:75: in function 'poll'
-- 	...amdegroot/torch/install/share/lua/5.1/lzmq/impl/loop.lua:307: in function 'poll'
-- 	...amdegroot/torch/install/share/lua/5.1/lzmq/impl/loop.lua:325: in function 'sleep_ex'
-- 	...amdegroot/torch/install/share/lua/5.1/lzmq/impl/loop.lua:370: in function 'start'
-- 	...rs/amdegroot/torch/install/share/lua/5.1/itorch/main.lua:381: in main chunk
-- 	[C]: in function 'require'
-- 	(command line):1: in main chunk
-- ...
